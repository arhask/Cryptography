# %%
"""
Miller- Rabin test for composite numbers
returns true if composite
"""
def MRtest(a, n):
    if n == 2:
        return False
    if n % 2 == 0:
        return True
    if gcd(a,n) > 1 and gcd(a,n) < n:
        print ("1")
        return True
    
    
    
    
    k = 0
    q = n -1
    while q % 2 == 0:
        q = q / 2 
        k = k + 1 
        
    a = sAm ( n, a, q)
    
    if a % n == 1:
        return False
    
    for i in range(0, k):
        if a % n == n - 1:
             return False
        a = (a^2)
        
    return True
