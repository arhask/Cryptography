# %%
"""
This algortihm find all the primitive roots mod p 
Returns a list of the primitive roots of p
"""
def primitive_roots(p):
    g = primitive_root(p)
    
    i = 1
    powers =[]
    while i >= 1 and i <= p - 2:
        if gcd(i, p-1) == 1:
            powers.append(i)        
        i = i + 1
        
    roots = []
    for k in powers:
        roots.append( g**k % p)
    
    return roots
